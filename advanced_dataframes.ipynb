# %%
import pandas as pd
import numpy as np
import os
import env

from pydataset import data

# %% [markdown]
# # Exercises II

# %%
# 1. Copy the users and roles DataFrames from the examples above.
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})

users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})

roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
# 2. What is the result of using a right join on the DataFrames?

users.merge(roles,
            left_on='role_id', 
            right_on='id', 
            how='right', 
            indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %%
# 3. What is the result of using an outer join on the DataFrames?

users.merge(roles,
            left_on='role_id', 
            right_on='id', 
            how='outer', 
            indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %%
# 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

users.drop(columns ='role_id').merge(roles,
            left_on='role_id', 
            right_on='id', 
            how='right', 
            indicator=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [37], in <cell line: 3>()
#       1 # 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?
# ----> 3 users.drop(columns ='role_id').merge(roles,
#       4             left_on='role_id',
#       5             right_on='id',
#       6             how='right',
#       7             indicator=True)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:9354, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9335 @Substitution("")
#    9336 @Appender(_merge_doc, indents=2)
#    9337 def merge(
#    (...)
#    9350     validate: str | None = None,
#    9351 ) -> DataFrame:
#    9352     from pandas.core.reshape.merge import merge
# -> 9354     return merge(
#    9355         self,
# ...

# %%
# 5. Load the mpg dataset from PyDataset.

mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
# 6. Output and read the documentation for the mpg dataset.

mpg = data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
# 7. How many rows and columns are in the dataset?

mpg.shape
# Out:
# (234, 11)

# %%
# 8. Check out your column names and perform any cleanup you may want on them.

mpg.rename(columns = {'cty':'city', 'hwy':'highway'}, inplace=True)
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class
# 1  compact
# 2  compact
# 3  compact
# 4  compact
# 5  compact

# %%
# 9. Display the summary statistics for the dataset.

mpg.describe()
# Out:
#             displ         year         cyl        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
# 10. How many different manufacturers are there?

# mpg['manufacturer'].unique()
# len(mpg['manufacturer'].unique())

mpg.manufacturer.nunique()
# Out:
# 15

# %%
# 11. How many different models are there?

# mpg['model'].unique()
# len(mpg['model'].unique())

mpg.model.nunique()
# Out:
# 38

# %%
# 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car

mpg['mileage_difference'] = abs(mpg.city - mpg.highway)
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_difference
# 1  compact                  11
# 2  compact                   8
# 3  compact                  11
# 4  compact                   9
# 5  compact                  10

# %%
# 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

mpg['average_mileage'] = (mpg['city'] + mpg['highway'])/ 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_difference  average_mileage
# 1  compact                  11             23.5
# 2  compact                   8             25.0
# 3  compact                  11             25.5
# 4  compact                   9             25.5
# 5  compact                  10             21.0

# %%
# 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# mpg['trans'].unique()
mpg['is_automatic'] = np.where(mpg.trans.str.startswith('a'),'Yes', 'No')
mpg.head()


# mpg['is_automatic'] = mpg.trans.str.startswith('a')
# mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_difference  average_mileage is_automatic
# 1  compact                  11             23.5          Yes
# 2  compact                   8             25.0           No
# 3  compact                  11             25.5           No
# 4  compact                   9             25.5          Yes
# 5  compact                  10             21.0          Yes

# %%
# 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

mpg.groupby('average_mileage').agg(max).tail(1)

# solution

# mpg.groupby('manufacturer')['average_mileage'].agg('mean').nlargest(1)
# Out:
#                 manufacturer       model  displ  year  cyl       trans drv  \
# average_mileage
# 39.5              volkswagen  new beetle    1.9  1999    4  manual(m5)   f
#
#                  city  highway fl       class  mileage_difference is_automatic
# average_mileage
# 39.5               35       44  d  subcompact                   9           No

# %%
# 16. Do automatic or manual cars have better miles per gallon?

mpg.groupby('is_automatic')[['average_mileage']].agg(max).tail()
# Out:
#               average_mileage
# is_automatic
# No                       39.5
# Yes                      35.0

# %% [markdown]
# # Exercises I

# %%
# 3. Create a function named get_db_url. It should accept a username, hostname, password, and database name 
# and return a url connection string formatted like in the example at the start of this lesson.

def get_db_url(db, env_file=os.path.exists('env.py')):
    '''
    return a formatted string containing username, password, host, and 
    database for connecting to the mySQL server and the database indicated
    '''
    if env_file:
        username, password, host = (env.username, env.password, env.host)
        return f'mysql+pymysql://{username}:{password}@{host}/{db}'
    else:
        return 'An error'

# %%
# 4. Use your function to obtain a connection to the employees database.

url = get_db_url('employees')

query = 'SELECT * FROM employees LIMIT 5'

df1 = pd.read_sql(query, url)

df1.head(1)
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26

# %%
# 5. Once you have successfully run a query:

# a. Intentionally make a typo in the database url. What kind of error message do you see?

# b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
url = get_db_url('mployees')

query1 = 'SELECT * FROM employees LIMIT 5'

df1 = pd.read_sql(query1, url)
df1
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
url = get_db_url('employees')

query1 = 'SELECT * FROM employees LMIT 5'

df1 = pd.read_sql(query1, url)
df1
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py:148, in Cursor.execute(self, query, args)
# ...

# %%
# 6.Read the employees and titles tables into two separate DataFrames.

url = get_db_url('employees')

query1 = 'SELECT * FROM employees'

df1 = pd.read_sql(query1, url)

df1.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
url = get_db_url('employees')

query1 = 'SELECT * FROM titles'

df2 = pd.read_sql(query1, url)

df2.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %%
# 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# df1.emp_no.count()

df1.shape
# Out:
# (300024, 6)

# %%
# df2.emp_no.count()

df2.shape
# Out:
# (443308, 4)

# %%
# 8. Display the summary statistics for each DataFrame.

df1.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
df2.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %%
# 9. How many unique titles are in the titles DataFrame?

# print(type(df2.title))
# print(df2.title.unique())
# print(type(df2.title.unique()))

len(df2.title.unique())
# Out:
# 7

# %%
df2.title.nunique()
# Out:
# 7

# %%
pd.Series(df2.title.unique()).count()
# Out:
# 7

# %%
pd.DataFrame(df2.title.unique()).count()
# Out:
# 0    7
# dtype: int64

# %%
# 10. What is the oldest date in the to_date column?

df2.to_date.agg('min')
# Out:
# datetime.date(1985, 3, 1)

# %%
# 11. What is the most recent date in the to_date column?

df2.to_date.agg('max')
# Out:
# datetime.date(9999, 1, 1)

# %%
unique_to_date = df2.to_date.unique()
pd.Series(unique_to_date).sort_values().tail(2) # calculates most recent date in the to_date column
# Out:
# 3489    2002-08-01
# 0       9999-01-01
# dtype: object

# %% [markdown]
# # Exercises III

# %%
url = get_db_url('chipotle')

query = 'SELECT * FROM orders'

orders = pd.read_sql(query, url)

orders.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %%
orders.dtypes
# Out:
# id                     int64
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
orders.item_price = orders.item_price.str.replace('$','').astype('float')
# Out:
# /var/folders/zx/rl1648955j94d0gt7b_0rshh0000gn/T/ipykernel_56825/3414115830.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   orders.item_price = orders.item_price.str.replace('$','').astype('float')

# %%
orders['price'] = orders.groupby(['order_id']).item_price.sum()

# %%
orders.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price  price
# 0        2.39    NaN
# 1        3.39  11.56
# 2        3.39  16.98
# ...

# %%
# 2. What is the total price for each order?

orders.groupby('order_id')['price'].agg('sum')
# Out:
# order_id
# 1       41.21
# 2       21.00
# 3       31.20
# 4       26.58
# 5       23.87
#         ...
# 1830     0.00
# 1831     0.00
# 1832     0.00
# 1833     0.00
# 1834     0.00
# Name: price, Length: 1834, dtype: float64

# %%
# solution

orders.groupby('order_id')['item_price'].agg('sum')
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %%
# 3. What are the most popular 3 items?

orders.item_name.value_counts()
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Steak Bowl                               211
# Chips                                    211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
orders.item_name.value_counts().head(3)
# Out:
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Name: item_name, dtype: int64

# %%
# solution

orders.groupby('item_name')['id'].count().nlargest(3)
# Out:
# item_name
# Chicken Bowl           726
# Chicken Burrito        553
# Chips and Guacamole    479
# Name: id, dtype: int64

# %%
# 4. Which item has produced the most revenue?

# %%
orders.groupby('item_name').price.sum().nlargest()
# Out:
# item_name
# Chicken Bowl           4787.85
# Chicken Burrito        4218.03
# Chips and Guacamole    3439.52
# Steak Burrito          2887.17
# Canned Soft Drink      2200.92
# Name: price, dtype: float64

# %%
orders.groupby('item_name').price.sum().nlargest(1)
# Out:
# item_name
# Chicken Bowl    4787.85
# Name: price, dtype: float64

# %%
# Solution
orders.groupby('item_name')['item_price'].agg('sum').nlargest(1)
# Out:
# item_name
# Chicken Bowl    7342.73
# Name: item_price, dtype: float64

# %%
# 5. Join the employees and titles DataFrames together

employees = df1.merge(df2, 
          left_on='emp_no', 
          right_on='emp_no', 
          how='outer',
         indicator=True
         )

# %%
df1.head(10)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10001  1953-09-02     Georgi    Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel     Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto    Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 5   10006  1953-04-20     Anneke    Preusig      F  1989-06-02
# 6   10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
# 7   10008  1958-02-19     Saniya   Kalloufi      M  1994-09-15
# 8   10009  1952-04-19     Sumant       Peac      F  1985-02-18
# 9   10010  1963-06-01  Duangkaew   Piveteau      F  1989-08-24

# %%
df2.head(10)
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01
# 5   10005     Senior Staff  1996-09-12  9999-01-01
# 6   10005            Staff  1989-09-12  1996-09-12
# 7   10006  Senior Engineer  1990-08-05  9999-01-01
# 8   10007     Senior Staff  1996-02-11  9999-01-01
# 9   10007            Staff  1989-02-10  1996-02-11

# %%
employees.head(10)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date  \
# 0   10001  1953-09-02     Georgi    Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel     Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto    Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 4   10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 5   10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 6   10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 7   10006  1953-04-20     Anneke    Preusig      F  1989-06-02
# 8   10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
# 9   10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
#
#              title   from_date     to_date _merge
# 0  Senior Engineer  1986-06-26  9999-01-01   both
# 1            Staff  1996-08-03  9999-01-01   both
# 2  Senior Engineer  1995-12-03  9999-01-01   both
# 3         Engineer  1986-12-01  1995-12-01   both
# ...

# %%
# 7. For each title, find the hire date of the employee that was hired most recently with that title.

# Solution

employees.groupby('title')['from_date'].agg('max')
# Out:
# title
# Assistant Engineer    2000-02-01
# Engineer              2002-08-01
# Manager               1996-08-30
# Senior Engineer       2002-08-01
# Senior Staff          2002-08-01
# Staff                 2000-02-01
# Technique Leader      2000-02-01
# Name: from_date, dtype: object

# %%
# 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data 
# and python/pandas code to perform the manipulations.)

# %%
# Solution

cross_querry = """
    SELECT t.title, d.dept_name
    FROM dept_emp
    JOIN titles t USING(emp_no)
    JOIN departments d USING(dept_no)
    WHERE t.to_date > NOW();
    """

# %%
url = get_db_url('employees')

# %%
df_cross = pd.read_sql(cross_querry, url)
df_cross.head()
# Out:
#              title        dept_name
# 0  Senior Engineer      Development
# 1            Staff            Sales
# 2  Senior Engineer       Production
# 3  Senior Engineer       Production
# 4     Senior Staff  Human Resources

# %%
df_cross.shape
# Out:
# (265332, 2)

# %%
pd.crosstab(df_cross['title'], df_cross['dept_name'])
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer                68         1833        0                0
# Engineer                         627        15677        0                0
# Manager                            1            1        1                1
# Senior Engineer                 1790        43364        0                0
# Senior Staff                   12349         1085    10650            10843
# Staff                           3902          315     3199             3416
# Technique Leader                 241         6117        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        1542                 433        77      0
# Engineer                    0       13325                3744       830      0
# Manager                     1           1                   1         1      1
# ...
